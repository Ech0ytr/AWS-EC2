# %%
# %%writefile hello.py
import streamlit as st

st.title('Hello World')

st.subheader('This is a simple Streamlit app')

name = st.text_input('What is your name?')

st.write('Hello, '+ name + '!')
# Out:
# Overwriting hello.py

# %%
# %%writefile requirements.txt
# streamlit
# Out:
# Overwriting requirements.txt

# %%
# %%writefile Dockerfile
# FROM python:3.9
# WORKDIR /app
# COPY requirements.txt requirements.txt
# RUN pip install -r requirements.txt
# COPY . .
# EXPOSE 8501
# CMD ["streamlit", "run", "hello.py", "--server.port=8501", "--server.address=0.0.0.0"]
# Out:
# Overwriting Dockerfile

# %%
FROM python:3.9
WORKDIR /app
COPY requirements.txt requirements.txt
RUN pip install -r requirements.txt
COPY . .  # Copy all contents of the current directory to the /app directory in the container
EXPOSE 8501
CMD ["streamlit", "run", "hello.py", "--server.port=8501", "--server.address=0.0.0.0"]
# Out:
#   Cell In[16], line 1
#     FROM python:3.9
#          ^
# SyntaxError: invalid syntax

# %%
# !docker build -t streamlit-hello-app .
# Out:
# [+] Building 0.0s (0/0)  docker:desktop-linux
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 251B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.2s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 0.4s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 251B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# ...

# %%
# !docker run -p 8501:8501 streamlit-hello-app
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   URL: http://0.0.0.0:8501
