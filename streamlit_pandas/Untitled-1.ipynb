# %%
# %%writefile hello.py
import pandas as pd
import streamlit as st

tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population")

df = tables[2]

col_names = [i[0] for i in df.columns]
df.columns = col_names

df_cut = df[df.columns[:3]]

st.title('Display the top 10 cities')
st.dataframe(df_cut)
st.bar_chart(df_cut['2023 estimate'])
# Out:
# Writing hello.py

# %%
# %%writefile requirements.txt
# streamlit
# pandas
# Out:
# Writing requirements.txt

# %%
# %%writefile Dockerfile
# FROM python:3.9
# WORKDIR /app
# COPY requirements.txt .
# RUN pip install -r requirements.txt
# COPY . .
# EXPOSE 8501
# CMD ["streamlit", "pandas", "run", "hello.py", "--server.port=8501", "--server.address=0.0.0.0"]
# Out:
# Overwriting Dockerfile

# %%
# !docker build -t streamlit-hello-app .
# Out:
# [+] Building 0.0s (0/0)  docker:desktop-linux
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.3s
# [+] Building 0.4s (2/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
# [+] Building 0.5s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
# [+] Building 0.7s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              0.1s
# [+] Building 0.8s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              0.3s
# [+] Building 1.0s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              0.4s
# [+] Building 1.1s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              0.6s
# [+] Building 1.3s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              0.8s
# [+] Building 1.4s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              0.9s
# [+] Building 1.6s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              1.0s
# [+] Building 1.7s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              1.2s
# [+] Building 1.9s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              1.4s
# [+] Building 2.0s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              1.5s
# [+] Building 2.2s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              1.6s
# [+] Building 2.3s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              1.8s
# [+] Building 2.5s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              1.9s
# [+] Building 2.6s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              2.1s
# [+] Building 2.8s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              2.2s
# [+] Building 2.9s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              2.4s
# [+] Building 3.1s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              2.5s
# [+] Building 3.2s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              2.7s
# [+] Building 3.4s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              2.8s
# [+] Building 3.5s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              3.0s
# [+] Building 3.6s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              3.1s
#  => => # Collecting streamlit
# [+] Building 3.8s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              3.3s
#  => => # Collecting streamlit
# [+] Building 3.8s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              3.3s
#  => => # Collecting streamlit
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
# [+] Building 4.0s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              3.5s
#  => => # Collecting streamlit
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
# [+] Building 4.1s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              3.6s
#  => => # Collecting streamlit
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
# [+] Building 4.3s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              3.7s
#  => => # Collecting streamlit
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
# [+] Building 4.4s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              3.9s
#  => => # Collecting streamlit
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
# [+] Building 4.6s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              4.0s
#  => => # Collecting streamlit
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
# [+] Building 4.7s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              4.2s
#  => => # Collecting streamlit
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
# [+] Building 4.8s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              4.3s
#  => => # Collecting streamlit
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
#  => => # Collecting pandas
# [+] Building 5.0s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              4.5s
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
#  => => # Collecting pandas
#  => => #   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (13.1 MB)
# [+] Building 5.1s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              4.6s
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
#  => => # Collecting pandas
#  => => #   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (13.1 MB)
# [+] Building 5.3s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              4.8s
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
#  => => # Collecting pandas
#  => => #   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (13.1 MB)
# [+] Building 5.4s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              4.9s
#  => => #   Downloading streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta
#  => => #  0:00:00
#  => => # Collecting pandas
#  => => #   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (13.1 MB)
# [+] Building 5.6s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              5.0s
#  => => #  0:00:00
#  => => # Collecting pandas
#  => => #   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (13.1 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 16.7 MB/s e
#  => => # ta 0:00:00
# [+] Building 5.7s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              5.2s
#  => => #  0:00:00
#  => => # Collecting pandas
#  => => #   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (13.1 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 16.7 MB/s e
#  => => # ta 0:00:00
# [+] Building 5.7s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              5.2s
#  => => # Collecting pandas
#  => => #   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux20
#  => => # 14_x86_64.whl (13.1 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 16.7 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting packaging<25,>=20
# [+] Building 5.9s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                              5.4s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 16.7 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting packaging<25,>=20
#  => => #   Downloading packaging-24.1-py3-none-any.whl (53 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 6.6 MB/s et
#  => => # a 0:00:00
# [+] Building 5.9s (7/9)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
# ...
# [+] Building 101.1s (9/10)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    51.2s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.2s
# [+] Building 101.3s (9/10)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    51.3s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.4s
# [+] Building 101.4s (9/10)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    51.5s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.5s
# [+] Building 101.6s (9/10)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    51.7s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.7s
# [+] Building 101.7s (9/10)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    51.8s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.8s
# [+] Building 101.8s (9/10)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    51.9s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.9s
# [+] Building 102.0s (10/10)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    52.0s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.9s
# [+] Building 102.2s (10/10)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    52.0s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.9s
# [+] Building 102.2s (10/10) FINISHED                       docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 236B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9              0.4s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => => resolve docker.io/library/python:3.9@sha256:ed8b9dd4e9f89c111f4bdb  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 335B                                          0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] COPY requirements.txt .                                          0.0s
#  => [4/5] RUN pip install -r requirements.txt                             49.1s
#  => [5/5] COPY . .                                                         0.3s
#  => exporting to image                                                    52.0s
#  => => exporting layers                                                   40.8s
#  => => exporting manifest sha256:fc9084d58ae6d5941520a7a231c3ceb8380fe1ca  0.0s
#  => => exporting config sha256:09a3203f27ee4e709f521bbf0890f184e8178e0f34  0.0s
#  => => exporting attestation manifest sha256:39a9488068e2eb8cec2d746860ea  0.0s
#  => => exporting manifest list sha256:9e11e01e6eaab9e19fb2c8cafd1e802612b  0.0s
#  => => naming to docker.io/library/streamlit-hello-app:latest              0.0s
#  => => unpacking to docker.io/library/streamlit-hello-app:latest          10.9s
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview
